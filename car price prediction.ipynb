# %%
import pandas as pd
import numpy as np

# %%
car=pd.read_csv('https://raw.githubusercontent.com/amankharwal/Website-data/master/CarPrice.csv')

# %%
car.shape
# Out:
# (205, 26)

# %%
car.head(3)
# Out:
#    car_ID  symboling                   CarName fueltype aspiration doornumber  \
# 0       1          3        alfa-romero giulia      gas        std        two
# 1       2          3       alfa-romero stelvio      gas        std        two
# 2       3          1  alfa-romero Quadrifoglio      gas        std        two
#
#        carbody drivewheel enginelocation  wheelbase  ...  enginesize  \
# 0  convertible        rwd          front       88.6  ...         130
# 1  convertible        rwd          front       88.6  ...         130
# 2    hatchback        rwd          front       94.5  ...         152
#
#    fuelsystem  boreratio  stroke compressionratio horsepower  peakrpm citympg  \
# 0        mpfi       3.47    2.68              9.0        111     5000      21
# 1        mpfi       3.47    2.68              9.0        111     5000      21
# 2        mpfi       2.68    3.47              9.0        154     5000      19
#
#    highwaympg    price
# 0          27  13495.0
# ...

# %%
car.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 205 entries, 0 to 204
# Data columns (total 26 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   car_ID            205 non-null    int64
#  1   symboling         205 non-null    int64
#  2   CarName           205 non-null    object
#  3   fueltype          205 non-null    object
#  4   aspiration        205 non-null    object
#  5   doornumber        205 non-null    object
#  6   carbody           205 non-null    object
#  7   drivewheel        205 non-null    object
#  8   enginelocation    205 non-null    object
#  9   wheelbase         205 non-null    float64
#  10  carlength         205 non-null    float64
#  11  carwidth          205 non-null    float64
#  12  carheight         205 non-null    float64
#  13  curbweight        205 non-null    int64
#  14  enginetype        205 non-null    object
#  15  cylindernumber    205 non-null    object
# ...

# %%
car.describe()
# Out:
#            car_ID   symboling   wheelbase   carlength    carwidth   carheight  \
# count  205.000000  205.000000  205.000000  205.000000  205.000000  205.000000
# mean   103.000000    0.834146   98.756585  174.049268   65.907805   53.724878
# std     59.322565    1.245307    6.021776   12.337289    2.145204    2.443522
# min      1.000000   -2.000000   86.600000  141.100000   60.300000   47.800000
# 25%     52.000000    0.000000   94.500000  166.300000   64.100000   52.000000
# 50%    103.000000    1.000000   97.000000  173.200000   65.500000   54.100000
# 75%    154.000000    2.000000  102.400000  183.100000   66.900000   55.500000
# max    205.000000    3.000000  120.900000  208.100000   72.300000   59.800000
#
#         curbweight  enginesize   boreratio      stroke  compressionratio  \
# count   205.000000  205.000000  205.000000  205.000000        205.000000
# mean   2555.565854  126.907317    3.329756    3.255415         10.142537
# ...

# %%
car.isnull().sum()
# Out:
# car_ID              0
# symboling           0
# CarName             0
# fueltype            0
# aspiration          0
# doornumber          0
# carbody             0
# drivewheel          0
# enginelocation      0
# wheelbase           0
# carlength           0
# carwidth            0
# carheight           0
# curbweight          0
# enginetype          0
# cylindernumber      0
# enginesize          0
# fuelsystem          0
# boreratio           0
# stroke              0
# compressionratio    0
# horsepower          0
# peakrpm             0
# citympg             0
# highwaympg          0
# price               0
# dtype: int64

# %%
car.duplicated().sum()
# Out:
# 0

# %%
#correlations between useful features and target
#find out the right features
#
import seaborn as sns

# %%
sns.heatmap(car.corr())
# Out:
# C:\Users\ANANYA\AppData\Local\Temp\ipykernel_9276\2241012700.py:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   sns.heatmap(car.corr())
# <Axes: >

# %%
print(car['horsepower'].corr(car['price']))
print(car['enginesize'].corr(car['price']))
print(car['carwidth'].corr(car['price']))
print(car['curbweight'].corr(car['price']))
print(car['carlength'].corr(car['price']))
# Out:
# 0.8081388225362215
# 0.8741448025245112
# 0.759325299741511
# 0.835304879337296
# 0.6829200156779621

# %%
df2 = car[['horsepower', 'enginesize','carwidth','curbweight','carlength','price']].copy()

# %%
df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 205 entries, 0 to 204
# Data columns (total 6 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   horsepower  205 non-null    int64
#  1   enginesize  205 non-null    int64
#  2   carwidth    205 non-null    float64
#  3   curbweight  205 non-null    int64
#  4   carlength   205 non-null    float64
#  5   price       205 non-null    float64
# dtypes: float64(3), int64(3)
# memory usage: 9.7 KB

# %%
df2.describe()
# Out:
#        horsepower  enginesize    carwidth   curbweight   carlength  \
# count  205.000000  205.000000  205.000000   205.000000  205.000000
# mean   104.117073  126.907317   65.907805  2555.565854  174.049268
# std     39.544167   41.642693    2.145204   520.680204   12.337289
# min     48.000000   61.000000   60.300000  1488.000000  141.100000
# 25%     70.000000   97.000000   64.100000  2145.000000  166.300000
# 50%     95.000000  120.000000   65.500000  2414.000000  173.200000
# 75%    116.000000  141.000000   66.900000  2935.000000  183.100000
# max    288.000000  326.000000   72.300000  4066.000000  208.100000
#
#               price
# count    205.000000
# mean   13276.710571
# std     7988.852332
# min     5118.000000
# 25%     7788.000000
# 50%    10295.000000
# 75%    16503.000000
# max    45400.000000

# %%
sns.heatmap(df2.corr(),annot=True)
# Out:
# <Axes: >

# %%
sns.pairplot(data=df2)

# %%
import matplotlib.pyplot as plt
#plt.hist(df2['price'],color='red')

plt.hist(df2['carwidth'],color='blue')
plt.hist(df2['curbweight'],color='green')
#plt.hist(df2['price'],color='red')*/
plt.show()

# %%
#since the values are in vary different ranges we have to scale the values in order to make them comparable

# %%
sns.scatterplot(x=df2['horsepower'],y=df2['price'])
# Out:
# <Axes: xlabel='horsepower', ylabel='price'>

# %%
#since car length and curbweight are highly correlated hence we take curbweight
df2.head(3)
# Out:
#    horsepower  enginesize  carwidth  curbweight  carlength    price
# 0         111         130      64.1        2548      168.8  13495.0
# 1         111         130      64.1        2548      168.8  16500.0
# 2         154         152      65.5        2823      171.2  16500.0

# %%
df2=df2.drop(columns=['carlength'])
df2.head()
# Out:
#    horsepower  enginesize  carwidth  curbweight    price
# 0         111         130      64.1        2548  13495.0
# 1         111         130      64.1        2548  16500.0
# 2         154         152      65.5        2823  16500.0
# 3         102         109      66.2        2337  13950.0
# 4         115         136      66.4        2824  17450.0

# %%
from sklearn.preprocessing import StandardScaler

# Extract the features to be normalized into a separate DataFrame
features_to_normalize = df2[['horsepower', 'enginesize', 'carwidth','curbweight']]

# Create a StandardScaler object
scaler = StandardScaler()

# Fit the scaler to the features
scaler.fit(features_to_normalize)

# Transform the features using the scaler
normalized_features = scaler.transform(features_to_normalize)

# Replace the original features in the DataFrame with the normalized ones
df2[['horsepower', 'enginesize', 'carwidth','curbweight']] = normalized_features

# %%
df2.head()
# Out:
#    horsepower  enginesize  carwidth  curbweight    price
# 0    0.174483    0.074449 -0.844782   -0.014566  13495.0
# 1    0.174483    0.074449 -0.844782   -0.014566  16500.0
# 2    1.264536    0.604046 -0.190566    0.514882  16500.0
# 3   -0.053668   -0.431076  0.136542   -0.420797  13950.0
# 4    0.275883    0.218885  0.230001    0.516807  17450.0

# %%
data=df2.values
x=data[:,0:4]

y=data[:,4]

# %%
#train test split
from sklearn.model_selection import train_test_split
xtrain,xtest,ytrain,ytest=train_test_split(x,y,test_size=0.2)

# %%
from sklearn.linear_model import LinearRegression
lr=LinearRegression()

# %%
lr.fit(xtrain,ytrain)
ypred=lr.predict(xtest)

# %%
lr.predict([[0.174483,	0.074449,	-0.844782,	-0.014566]])
# Out:
# array([13022.5602511])

# %%
from sklearn.metrics import r2_score
ac=r2_score(ytest, ypred)
ac
# Out:
# 0.8544470220231525
